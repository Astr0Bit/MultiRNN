# %% [markdown]
# ### P.S. This file is the same as 'test/method_testing.ipynb'

# %%
import sys

if "../" not in sys.path:
    sys.path.append("../")

from multirnn import MultiRNN
# Out:
# 2024-06-05 11:27:42.821476: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-05 11:27:42.821595: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-05 11:27:42.831459: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-05 11:27:42.859201: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
sys.path
# Out:
# ['/home/emil/yes/envs/global_env/lib/python310.zip',
#  '/home/emil/yes/envs/global_env/lib/python3.10',
#  '/home/emil/yes/envs/global_env/lib/python3.10/lib-dynload',
#  '',
#  '/home/emil/yes/envs/global_env/lib/python3.10/site-packages',
#  '../']

# %%
import pandas as pd
df = pd.read_csv("../data/energydata_complete.csv",
                 index_col="date", parse_dates=True)
df.head()
# Out:
#                      Appliances  lights     T1       RH_1    T2       RH_2  \
# date
# 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#                         T3       RH_3         T4       RH_4  ...         T9  \
# date                                                         ...
# 2016-01-11 17:00:00  19.79  44.730000  19.000000  45.566667  ...  17.033333
# 2016-01-11 17:10:00  19.79  44.790000  19.000000  45.992500  ...  17.066667
# 2016-01-11 17:20:00  19.79  44.933333  18.926667  45.890000  ...  17.000000
# 2016-01-11 17:30:00  19.79  45.000000  18.890000  45.723333  ...  17.000000
# ...

# %%
len(df) # perhaps test_size of 0.15
# Out:
# 19735

# %%
test_size = 288 * 2 # 4 days
split_index = len(df) - test_size
split_index
# Out:
# 19159

# %%
length = 288
train = df.iloc[:split_index]
test = df.iloc[split_index:]

# %%
# for testing purposes, only 2 models will be made,
# and parameters are set to low values,
# further information is found in "multirnn.py" at line 165

# create a MultiRNN object
multi = MultiRNN(train=train, test=test,
                 length=288, LSTM_units=32, # 32 for testing
                 activation="tanh", optimizer="adam",
                 batch_size=10, epochs=5, # 5 for testing
                 )
# Out:
# 2024-06-05 11:27:45.367715: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-05 11:27:45.622721: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-05 11:27:45.622787: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-05 11:27:45.630720: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
multi.save_datasets(dir_path="../col_data") # save datasets

# %%
multi.save_scalers(dir_path="../col_data") # save scalers for later use

# %%
multi.save_scaled_datasets(dir_path="../col_data") # scaled datasets are saved in the same directory as the datasets

# %%
multi.fit_models() # fit models
# Out:
# Training model: 'Appliances_model'
# Epoch 1/5
# 2024-06-05 11:31:55.731024: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fcc0789e980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-06-05 11:31:55.731123: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2024-06-05 11:31:55.769245: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717579915.965346  106260 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1888/1888 [==============================] - 152s 79ms/step - loss: 0.0094 - val_loss: 0.0181
# Epoch 2/5
# ...

# %%
multi.save_models(dir_path="../models") # save models
# Out:
# /home/emil/yes/envs/global_env/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
multi.predict() # predict on test data
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step

# %%
# plot predictions against test data --> if re-run should show a plot
multi.plot_predictions(column="Appliances",
                       figure_height=5,
                       figure_width=5,
                       save_plot=True,
                       save_plot_name="../plots/Appliances.png")

# %%
# plot loss and validation loss per column
multi.plot_loss(column="Appliances",
                figure_width=5,
                figure_height=5,
                save_plot=True,
                save_plot_name="../plots/loss_val_loss_per_column.png")
